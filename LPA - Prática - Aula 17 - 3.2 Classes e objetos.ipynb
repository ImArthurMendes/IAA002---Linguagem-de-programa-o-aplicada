# %% [markdown]
# # LPA - Prática - Aula 17 - 3.2 Classes e objetos
# ### Parte 1: Classes
# #### Para criar uma classe, utiliza-se a palavra reservada class, O nome da sua classe segue a mesma convenção de nomes para criação de funções e variáveis, mas normalmente se usa a primeira letra maiúsucla em cada palavra no nome

# %%
# Criando uma classe chamada livro
class Livro():
    
    # Este método vai inicializar cada objeto criado a apartir dessa classe
    # O nome desse método é __init__
    # (self) é uma refernência a cada atributo de um objeto criado a partiri dessa classe
    def __init__ (self):
        
        # Atributos de cada objeto criado a partir desta classe
        # O self indica que estes são atributos dos objetos
        self.titulo='Sapiens - Uma história da humanidade.'
        self.isbn=777101010
        print('Construtor chamado para criar um objeto desta classe')
    
    # Métodos são funções, que recebem como parâmetro atributos do objeto criado
    def imprime(self):
        print('Foi criado o livro %s e seu ISBN é %d' %(self.titulo,self.isbn))

# %%
# Criando uma instância (objeto) da classe livro
Livro1=Livro()
# Out:
# Construtor chamado para criar um objeto desta classe

# %%
# Tipo do objeto criado a partir da classe livro (__main__ é um objeto)
type(Livro1)
# Out:
# __main__.Livro

# %%
# Atributo do objeto Livro1
Livro1.titulo
# Out:
# 'Sapiens - Uma história da humanidade.'

# %%
# Método do objeto Livro1
Livro1.imprime()
# Out:
# Foi criado o livro Sapiens - Uma história da humanidade. e seu ISBN é 777101010
